# %%
import pandas as pd
import numpy as np
import pprint
import operator
import re

pd.options.display.max_columns = None

# %%
df = pd.read_csv('./jdp_2016.csv')
df.shape
# Out:
# (3950, 41)

# %%
df.head()
# Out:
#   iqs_verbatim_2016.vin iqs_verbatim_2016.vin7 iqs_verbatim_2016.squish_vin  \
# 0     WBA3R1C53GK529759                K529759                   WBA3R1C5GK
# 1     5UXKR0C58G0P29524                0P29524                   5UXKR0C5G0
# 2     5UXKR0C58G0P29524                0P29524                   5UXKR0C5G0
# 3     5UXWZ7C52G0T42543                0T42543                   5UXWZ7C5G0
# 4     WBAKP9C57GD980259                D980259                   WBAKP9C5GD
#
#   iqs_verbatim_2016.sequence_number iqs_verbatim_2016.make  \
# 0                          2547672J                    BMW
# 1                          2282786S                    BMW
# 2                          2282786S                    BMW
# 3                          25446029                    BMW
# 4                          2405696S                    BMW
#
#   iqs_verbatim_2016.series iqs_verbatim_2016.model_and_type  \
# 0                 4 Series             BMW 4 Series 2dr Cpe
# ...

# %%
bmw_df = df[df['iqs_verbatim_2016.make']=='BMW']
mini_df = df[df['iqs_verbatim_2016.make']=='MINI']

# %%
new_df = pd.concat([bmw_df,mini_df],ignore_index=True)
new_df = new_df.fillna("")
new_df['iqs_verbatim_2016.verbatim'] = new_df['iqs_verbatim_2016.verbatim'].replace(to_replace='\(([^)]+)\)',value='',regex=True)
print(new_df.shape)
new_df.head()
# Out:
# (3950, 41)
#   iqs_verbatim_2016.vin iqs_verbatim_2016.vin7 iqs_verbatim_2016.squish_vin  \
# 0     WBA3R1C53GK529759                K529759                   WBA3R1C5GK
# 1     5UXKR0C58G0P29524                0P29524                   5UXKR0C5G0
# 2     5UXKR0C58G0P29524                0P29524                   5UXKR0C5G0
# 3     5UXWZ7C52G0T42543                0T42543                   5UXWZ7C5G0
# 4     WBAKP9C57GD980259                D980259                   WBAKP9C5GD
#
#   iqs_verbatim_2016.sequence_number iqs_verbatim_2016.make  \
# 0                          2547672J                    BMW
# 1                          2282786S                    BMW
# 2                          2282786S                    BMW
# 3                          25446029                    BMW
# 4                          2405696S                    BMW
#
#   iqs_verbatim_2016.series iqs_verbatim_2016.model_and_type  \
# 0                 4 Series             BMW 4 Series 2dr Cpe
# ...

# %%
import nltk
nltk.download('subjectivity')
nltk.download('vader_lexicon')
from nltk.classify import NaiveBayesClassifier
from nltk.corpus import subjectivity
from nltk.sentiment import SentimentAnalyzer
from nltk.sentiment.util import *
# Out:
# [nltk_data] Downloading package subjectivity to
# [nltk_data]     /home/qtc5712/nltk_data...
# [nltk_data]   Package subjectivity is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /home/qtc5712/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# /projects/qtb2630/NA_Data_Science/envs/py3/lib/python3.5/site-packages/nltk/twitter/__init__.py:20: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn("The twython library has not been installed. "

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
verbatim = new_df['iqs_verbatim_2016.verbatim'].tolist()

# %%
sid = SentimentIntensityAnalyzer()

# %%
i = 0
makes = []
series = []
problems = []
#categories = []
modes = []
statements = []
scores = []

for entry in verbatim:
    #print("{0}".format(new_df.loc[i,'Model and Type']))
    #print("Total Problems: {0}, Category: {1}, Mode: {2}".format(new_df.loc[i,'Total Problems'],new_df.loc[i,'Category'],new_df.loc[i,'Mode']))
    #print(entry)
    ss = sid.polarity_scores(entry)
    j = 0
    for k in sorted(ss):
        #print('{0}: {1}, '.format(k,ss[k]),end='')
        if j == 0:
            scores.append(ss[k])
            j+=1
    #print("\n")
    
    makes.append(new_df.loc[i,'iqs_verbatim_2016.make'])
    series.append(new_df.loc[i,'iqs_verbatim_2016.series'])
    problems.append(new_df.loc[i,'iqs_verbatim_2016.totalproblems'])
    #categories.append(new_df.loc[i,'iqs_verbatim_2016.category'])
    modes.append(new_df.loc[i,'iqs_verbatim_2016.malfunction_design_unknown'])
    statements.append(entry)
    
    i+=1

# %%
stuff = [('Make',makes), ('Series',series), ('Total_Problems',problems), ('Mode',modes), ('Verbatim',statements), ('Score',scores)]
new_new_df = pd.DataFrame.from_items(stuff)
new_new_df.head()
# Out:
#   Make    Series  Total_Problems Mode  \
# 0  BMW  4 Series               1
# 1  BMW        X5               2    D
# 2  BMW        X5               2    D
# 3  BMW        X3               1    D
# 4  BMW  5 Series               1    M
#
#                                             Verbatim   Score
# 0  : Passenger side vent selection to all three z... -0.7351
# 1                                                     0.0000
# 2                                                     0.0000
# 3                                                     0.0000
# 4  : Power trunk opening feature doesn't work as ... -0.3182

# %%
new_new_df.to_csv('2016_sentiments.csv')
